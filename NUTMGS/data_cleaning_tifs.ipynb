# %%
import os
folders = os.listdir('./tifs_for_labeling/rajasthan_top_10_tifs/')
folders
# Out:
# ['43da1359-7b3a-480b-a33b-aacfc11c97aa',
#  'c366d3ce-36a0-4fb3-a57b-44ff50d70ba2',
#  'f14cb4ad-eea8-495c-824f-02a8f828445d',
#  '4adc4ce1-bc39-44ae-a4d1-1f88d077a6d9',
#  '10db1e2e-76ff-4e58-988f-b2a4c1a3ba62',
#  '181d0f9c-e3b6-4b64-a814-e7219e719ce6',
#  '7999e3bc-b659-4fb9-b2b7-34d91e02cd7a',
#  '9595942f-5dfb-4c68-8aae-d47a51ccf55c',
#  '4d15653a-898c-46d4-9730-05f79531dc2b',
#  'd647a13a-8e93-4aae-840a-b680047fd305',
#  'eb87aa25-3e6f-40d9-945e-743a617640f4',
#  '820330d7-1c39-4711-abe7-6c001988b8f5',
#  '5b039f7e-ef34-4c08-bcf7-3b06257e1ec2',
#  '19abee1d-2c16-452b-96fd-ccb826b5e97f',
#  'e84b38e8-1d5d-4b3d-8517-1c8d8d01d60b',
#  '6d08c68f-5daa-4b65-8bc6-1438bc8854c6',
#  'fd9d591a-e13d-4cf7-ab0a-a8cbdda86aa0',
#  '9766746c-838d-4407-8b98-46714b80d52a',
#  'af81778b-6c32-42c0-b468-f44a37cfe170',
#  'af4acdcf-6375-48dc-bdf1-16b5098d7ced',
#  'f812f7ff-9c67-4970-97bd-1f5ce98689cf',
#  '48141d21-b697-44be-90ae-fc54e5d7bb1e',
#  '5b739443-b5c7-44cd-91f6-f57e1534a250',
# ...

# %%
import shutil

base = './tifs_for_labeling/rajasthan_top_10_tifs'

new_base = './tifs_for_labeling_cleaned/rajasthan_top_10_tifs'
os.mkdir(new_base)

for folder in folders:
    shutil.copytree(f'{base}/{folder}/SkySatScene', 
                    f'{new_base}/{folder}')
