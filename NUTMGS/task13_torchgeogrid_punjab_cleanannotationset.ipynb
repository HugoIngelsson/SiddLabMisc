# %%
import os
import tempfile
from urllib.parse import urlparse
import geopandas as gpd
from shapely import Point

import matplotlib.pyplot as plt
# import planetary_computer
# import pystac
import torch
from torch.utils.data import DataLoader
from torchgeo.datasets import RasterDataset, stack_samples, unbind_samples
from torchgeo.datasets.utils import download_url
from torchgeo.samplers import RandomGeoSampler, GridGeoSampler

from rasterio.transform import from_bounds

# %matplotlib inline
plt.rcParams["figure.figsize"] = (12, 12)

# %% [markdown]
# ## Input

# %% [markdown]
# #### in this we will be using the shapefile that we created from task11_skysat_scene_filtering of the chosen scenes that are not overlapping

# %%
class Skysat(RasterDataset):
    filename_glob = "*.tif"
    filename_regex = r"()"
    date_format = "%Y%m%d"
    is_image = True
    separate_files = True
    all_bands = ["red", "green", "blue"]
    rgb_bands = ["red", "green", "blue"]
    
    def __getitem__(self, index):
        sample_dict = super().__getitem__(index)

        # Convert image to tensor here, so that we can handle the bands
        # Compute the affine transform for this image
        image = sample_dict['image']

        transform = self.get_transform(sample_dict["bounds"], image.shape[1], image.shape[2])
        sample_dict["transform"] = transform
        return sample_dict

    def get_transform(self, bounds, height, width):
        # Convert a BoundingBox in pixel coordinates to an affine transform
        left, top, right, bottom = bounds.minx, bounds.maxy, bounds.maxx, bounds.miny
        return from_bounds(left, bottom, right, top, width, height)
    
    def plot(self, sample):
#         print(sample)
        # Find the correct band index order
        rgb_indices = []
        for band in self.rgb_bands:
            rgb_indices.append(self.all_bands.index(band))

        # Reorder and rescale the image
        image = sample["image"][rgb_indices].permute(1, 2, 0).numpy().astype(int)
#         image = torch.clamp(image / 10000, min=0, max=1).numpy()
#         print(image)
        # Plot the image
        fig, ax = plt.subplots()
        ax.imshow(image)

        return fig

# %%
# !ls /Users/siddharthsachdeva/repos/agroforestry/notebooks/exploration/karnataka_clearannotationset1/030b0be1-a128-4a58-805d-def84e5dab92/
# Out:
# SkySatScene   manifest.json

# %%
clear_imgs = ['20220418_050008_ssc2d2_0061_visual',
 '20220415_083158_ssc9d2_0002_visual',
 '20220418_051036_ssc13d1_0004_visual',
 '20220416_065524_ssc19d1_0054_visual',
 '20220427_053104_ss01d1_0022_visual',
 '20220429_053415_ss01d3_0007_visual',
 '20220424_052803_ss01d2_0009_visual',
 '20220411_084414_ssc8d3_0013_visual',
 '20220428_051006_ssc2d2_0012_visual',
 '20220428_051006_ssc2d2_0012_visual',
 '20220429_083200_ssc10d2_0006_visual',
 '20220417_051528_ssc12d1_0025_visual',
 '20220427_083312_ssc7d3_0010_visual',
 '20220416_083956_ssc7d3_0027_visual',
 '20220422_084107_ssc8d3_0014_visual',
 '20220425_052817_ss01d2_0026_visual'
]
len(clear_imgs)
# Out:
# 16

# %%
# dataset = Skysat('/Users/siddharthsachdeva/repos/agroforestry/notebooks/exploration/data/test_quality/images/Punjab_testcollects/')
# dataset = Skysat('./cali/')
dataset = Skysat('../../SpeciesMapping/DATA/karnataka_north_east_dry/')
print(dataset)
# Out:
# Skysat Dataset
#     type: GeoDataset
#     bbox: BoundingBox(minx=693271.5, maxx=699644.0, miny=1842451.0, maxy=1856252.5, mint=0.0, maxt=9.223372036854776e+18)
#     size: 15

# %%
sampler = GridGeoSampler(dataset, size=400, stride=400)
dataloader = DataLoader(dataset, sampler=sampler, collate_fn=stack_samples)
print(sampler.length)
# Out:
# 8288

# %%
# !mkdir /Users/siddharthsachdeva/Downloads/karnataka_skysatimages/

# %%
# Out:
# ['1205Z2BBA3_chipid1666.tiff',
#  'H6H7RH92PJ_chipid512.tiff',
#  '229PJFARSE_chipid266.tiff',
#  'WXDWLL549S_chipid3260.tiff',
#  '7SICQVL0NP_chipid1239.tiff',
#  '2HM3ML8UZJ_chipid128.tiff',
#  '0Z5NLNHAU2_chipid330.tiff',
#  'KTQZTERFG1_chipid519.tiff',
#  '1UFVFKT4CR_chipid414.tiff',
#  'IB2T8IDDHD_chipid1429.tiff',
#  'V2B9QPUDIP_chipid1374.tiff',
#  'XJMGY1GQT3_chipid953.tiff',
#  '5Q0M6QYLDZ_chipid342.tiff',
#  'Q4QT07BX9A_chipid783.tiff',
#  'GX62B66UK5_chipid2925.tiff',
#  'BK7BTRFSBS_chipid615.tiff',
#  '6EGZF4IQUT_chipid2575.tiff',
#  '44O3R4PQGJ_chipid408.tiff',
#  'KICM5PACNK_chipid2128.tiff',
#  'FA1R09V5JW_chipid3129.tiff',
#  '1F4D94JSWF_chipid1982.tiff',
#  'M7F4XVUPWN_chipid2178.tiff',
#  '2RZZIERKKD_chipid1438.tiff',
#  'R428B9PRM1_chipid1340.tiff',
#  'TR7Z2K496W_chipid2899.tiff',
#  '5RNX38WO6Q_chipid2489.tiff',
#  'TDPCG7SKS1_chipid2977.tiff',
#  '6ML4NP3Z4D_chipid2976.tiff',
#  'SWH5GHI7AD_chipid2794.tiff',
#  'XSZ7UUTBQQ_chipid2524.tiff',
#  'RDODWN65SL_chipid957.tiff',
#  'ATTGY2ST4Z_chipid2008.tiff',
#  'G9TEJXQDJ0_chipid1840.tiff',
#  'X697X6KDS7_chipid2660.tiff',
#  'WWS32JW20A_chipid1731.tiff',
#  'X6AA46PD6R_chipid1776.tiff',
#  'ORPGDATUUQ_chipid387.tiff',
#  'B8VQ4YQZUV_chipid1484.tiff',
#  'HV6634AR5I_chipid3100.tiff',
#  'F0F8B2ZISK_chipid1122.tiff',
#  'NQXRSHGMJQ_chipid2282.tiff',
#  'PUNXA5R9RO_chipid2962.tiff',
#  '9VIO53Q6TI_chipid714.tiff',
#  'FXULLVVJN4_chipid908.tiff',
#  '9QQKZ44935_chipid499.tiff',
#  '8MJTVX1ALD_chipid3201.tiff',
#  'WGREAZR987_chipid1052.tiff',
#  '7LWTZWMQSL_chipid376.tiff',
#  'MRI48MGGG1_chipid1765.tiff',
#  'OS0O028JUD_chipid2421.tiff',
#  'OJC97731PP_chipid868.tiff',
#  'QF68QOBGAG_chipid914.tiff',
#  '4MJKYI0VGT_chipid3004.tiff',
#  '2VES04DH7U_chipid587.tiff',
#  'LL3HGE9OUU_chipid2731.tiff',
#  'QRM48IU30P_chipid2194.tiff',
#  'ZKXZAA0BM0_chipid2337.tiff',
#  '0QEWDTEK7Z_chipid2963.tiff',
#  'FCGV6DE53D_chipid2236.tiff',
#  '12X9DN3UYT_chipid3103.tiff',
#  '7V4PTZLUFR_chipid318.tiff',
#  'EVUCC52I3Z_chipid3197.tiff',
#  'H05IH5BBAH_chipid2593.tiff',
#  'T84SIFP8LK_chipid700.tiff',
#  'E7JXS8TGAO_chipid2471.tiff',
#  'M2VJSS9V8K_chipid2397.tiff',
#  'J7DLNT7E8H_chipid207.tiff',
#  'AZQL4Z3WPZ_chipid256.tiff',
#  '8VZ6O30ZPU_chipid394.tiff',
#  '070AOY42YE_chipid746.tiff',
#  '1LYSVCV7XB_chipid569.tiff',
#  'HB7TGFUZ9X_chipid1397.tiff',
#  '3YUBIBGZS2_chipid807.tiff',
#  'HQ96E402PU_chipid2296.tiff',
#  'S18R1DCNDS_chipid1453.tiff',
#  'ACIT7LTJYQ_chipid3134.tiff',
#  '3Q9TJYDRUG_chipid778.tiff',
#  '0YUIG2MKHI_chipid2209.tiff',
#  'URYVKQCS02_chipid3198.tiff',
#  'U1E2DD1FWE_chipid1599.tiff',
#  'LL6KYT73H5_chipid2537.tiff',
#  '9F4W4587HI_chipid2888.tiff',
#  'A1DLLBT780_chipid18.tiff',
#  'KMYSHBVP4M_chipid2771.tiff',
#  'SD1RWA7I76_chipid2201.tiff',
#  '7L32JEH3RF_chipid1960.tiff',
#  '0PGN1WOWKC_chipid2760.tiff',
#  '53PUB9R3AI_chipid2984.tiff',
#  'JRDQ9TV3VY_chipid2238.tiff',
#  'APWC3NR7BV_chipid242.tiff',
#  'RR4C0HH79T_chipid1352.tiff',
#  'TCVSK6V9EY_chipid2202.tiff',
#  'OIHRC19D29_chipid1697.tiff',
#  '8AO9NSPTNI_chipid2365.tiff',
#  'UQJ6IPZ33J_chipid1012.tiff',
#  'E6E0YDT0TV_chipid1758.tiff',
#  '83BFGD0S5G_chipid2235.tiff',
#  'I7PYCKSI1Z_chipid3040.tiff',
#  'D5FNSPSSEO_chipid1701.tiff',
#  'V0I5XJGZTG_chipid1722.tiff',
#  'AZ4ZQ53BYU_chipid2147.tiff',
#  '6GV5OS8D8A_chipid2162.tiff',
#  'X5GCVSGG2Y_chipid2085.tiff',
#  '1QEEGJTN83_chipid188.tiff',
#  '10JXB0HCQM_chipid1465.tiff',
#  'UJB8TPVQQJ_chipid2226.tiff',
#  'CHOZKA9HEZ_chipid70.tiff',
#  'DPGA6AP8AE_chipid971.tiff',
#  'NDXVRK42GM_chipid2221.tiff',
#  'AQKC1GMEBE_chipid1703.tiff',
#  'D5OECA0E9B_chipid3124.tiff',
#  'JJQQUQBTT5_chipid87.tiff',
#  '383XDATT72_chipid1335.tiff',
#  'IAEHYHFODX_chipid1604.tiff',
#  '11GJD0IVD1_chipid2938.tiff',
#  'CPNXN6V2ZJ_chipid575.tiff',
#  'XZRM1TS9MA_chipid46.tiff',
#  'ANCLFAREJL_chipid378.tiff',
#  'HK8WQKN1FO_chipid348.tiff',
#  'NCFGTQ0FTT_chipid1387.tiff',
#  'MQMDZOL572_chipid620.tiff',
#  'R50VQ1WVEP_chipid2242.tiff',
#  'YII72BEXBM_chipid375.tiff',
#  'BPLRFDSB5P_chipid1975.tiff',
#  'VSJPJSV0K2_chipid1978.tiff',
#  'XFSLM90LTW_chipid3180.tiff',
#  'I9KDNNGAPX_chipid1099.tiff',
#  'HTEL0NZDQU_chipid1596.tiff',
#  'YTUU2CSJS2_chipid1176.tiff',
#  '0RTL8WZVXD_chipid1113.tiff',
#  'PPJXZV11MQ_chipid1355.tiff',
#  '3EZMXGQLQ3_chipid998.tiff',
#  '6121192Q4O_chipid1322.tiff',
#  'JC46JT49SM_chipid3245.tiff',
#  'O2SBKW82YV_chipid2532.tiff',
#  'CE41N5R69R_chipid228.tiff',
#  'TJ3J0TL25K_chipid2646.tiff',
#  'T16A7JB0HK_chipid2152.tiff',
#  '7YI893D18Y_chipid319.tiff',
#  '7RSKAG7IBV_chipid1609.tiff',
#  'SSKZ0B3YVO_chipid2312.tiff',
#  'E4HJTG5QUJ_chipid1685.tiff',
#  '993BZCANDF_chipid150.tiff',
#  'SK6F0WKAWL_chipid2934.tiff',
#  '8WZM6POKK2_chipid271.tiff',
#  'J5TA7VMWA1_chipid423.tiff',
#  'P6CKRUEQPS_chipid1760.tiff',
#  'L1WHWP9B3Y_chipid3223.tiff',
#  '1ON49W01ZD_chipid426.tiff',
#  '6RERDRU1TA_chipid1307.tiff',
#  'LEI93BSF4U_chipid848.tiff',
#  'BT78GFWSUH_chipid193.tiff',
#  'WLRMPRD5SV_chipid570.tiff',
#  'YK0NZB44NM_chipid2233.tiff',
#  '7BHLO49XO9_chipid202.tiff',
#  'WZZTBN0Q4K_chipid671.tiff',
#  '7DXU45VV2N_chipid2260.tiff',
#  'WMIOY6XVME_chipid1774.tiff',
#  'RTERFF0U63_chipid169.tiff',
#  'FE5XHONKYF_chipid2087.tiff',
#  '4OGENITVMN_chipid1089.tiff',
#  'USSQ2EJ3JW_chipid2612.tiff',
#  '00AP8TRIMJ_chipid3020.tiff',
#  '86BBFK3RTE_chipid2430.tiff',
#  'X6VGKYF0PA_chipid2792.tiff',
#  'KPQYNJ1HPU_chipid1107.tiff',
#  'RVCVZ6EC6X_chipid2281.tiff',
#  'HQL5JZ4K4G_chipid2756.tiff',
#  'BC54MOANYR_chipid3074.tiff',
#  'GG83MOAB1I_chipid1296.tiff',
#  '2OVQSUFAPM_chipid2701.tiff',
#  'JVF1P979UE_chipid2559.tiff',
#  'AFKRUU9QRT_chipid547.tiff',
#  'HMLSE9BAJF_chipid1251.tiff',
#  '11GAKKZYNR_chipid1588.tiff',
#  '0PQ37EOW9G_chipid1742.tiff',
#  'NCNBZE1D81_chipid3032.tiff',
#  '20MXDMEG6R_chipid2886.tiff',
#  'UPQY04QLAU_chipid1789.tiff',
#  'URBRNTE17Z_chipid1700.tiff',
#  'SCN2YLA4LX_chipid1786.tiff',
#  'OTVWSJD2U3_chipid2208.tiff',
#  'Y9I85RKUHU_chipid521.tiff',
#  'YIGLE5DAFS_chipid1824.tiff',
#  'NYG290F327_chipid622.tiff',
#  '6VCPEC9FI5_chipid576.tiff',
#  'NY7N1ACJVF_chipid3158.tiff',
#  '7JPDGXDKFA_chipid148.tiff',
#  'QGXKUBWYWK_chipid2239.tiff',
#  'ACS70E7IR0_chipid288.tiff',
#  '5QH4R0SB2G_chipid2930.tiff',
#  '5LQ9HLI8IS_chipid2520.tiff',
#  'NRO8WP9R4D_chipid2307.tiff',
#  'LBRINS7MLS_chipid357.tiff',
#  'CLLA0XIAMD_chipid1179.tiff',
#  'A92KD91OWN_chipid1883.tiff',
#  'NBTAM2QWHU_chipid1497.tiff',
#  'H82O75PC75_chipid1747.tiff',
#  'T3K1IFG3MK_chipid238.tiff',
#  'DTBIZ9UZEE_chipid2016.tiff',
#  'XW7CVQX1F4_chipid136.tiff',
#  'M1J0G9QPN5_chipid3057.tiff',
#  'Y7ROJR25EZ_chipid117.tiff',
#  'L3V7FL37MN_chipid2944.tiff',
#  '12QKV7P00C_chipid2267.tiff',
#  'W3GBL0SG3V_chipid2363.tiff',
#  'ZXRT015MQZ_chipid233.tiff',
#  'UHK5X13J0L_chipid2422.tiff',
#  'EZUNQ925C0_chipid3001.tiff',
#  'N9573PX1JV_chipid531.tiff',
#  'O52MT2KD93_chipid643.tiff',
#  'G93Z43FX0X_chipid2433.tiff',
#  'DJK4J8TWY1_chipid2937.tiff',
#  'PA8SSP6KRK_chipid2751.tiff',
#  '7CIWCF6DB7_chipid2261.tiff',
#  'Q4S8HCG435_chipid1616.tiff',
#  'YWPWKE236A_chipid176.tiff',
#  'FKOGF7GREV_chipid2328.tiff',
#  '5VFK25V1K9_chipid1316.tiff',
#  'QL82DYZYPP_chipid1625.tiff',
#  '1AXD40NGOX_chipid2622.tiff',
#  'OOWN5LXP0T_chipid338.tiff',
#  'AO06XAFR16_chipid1165.tiff',
#  'J0K4O3AU77_chipid2474.tiff',
#  '6YOFR56YRN_chipid2410.tiff',
#  'D76X4PBS4E_chipid2318.tiff',
#  'U4631BFO0C_chipid2578.tiff',
#  '4MVGVLVCQQ_chipid443.tiff',
#  '6GLQ2M6TC2_chipid2765.tiff',
#  'UNCPCMG9HO_chipid1847.tiff',
#  'QB1TZ6FZVW_chipid2563.tiff',
#  'JLQUGD50NQ_chipid2286.tiff',
#  'W9UPFL53GK_chipid2942.tiff',
#  '5XXVJS0KPY_chipid190.tiff',
#  'O1WY66O55K_chipid157.tiff',
#  'WHJEZ0UNS1_chipid2289.tiff',
#  'TE09K3GSLK_chipid2193.tiff',
#  'TVNBU5I9F4_chipid2047.tiff',
#  'YXSRNQFIPJ_chipid1324.tiff',
#  'XC5GP99E18_chipid694.tiff',
#  '6PDO5NAAR6_chipid2330.tiff',
#  'RDYWWZ6LL4_chipid433.tiff',
#  'A6M1OPIH73_chipid3056.tiff',
#  '07Z1CWX2L8_chipid1825.tiff',
#  'B4UXDO9QOG_chipid721.tiff',
#  '93GAGREKB5_chipid883.tiff',
#  '0L6S1V8ZFF_chipid1874.tiff',
#  'FCKJUCFUAA_chipid115.tiff',
#  'U08QER33YG_chipid130.tiff',
#  'D6XVNG2VQY_chipid2102.tiff',
#  'INRK085PGN_chipid770.tiff',
#  'R0LO6TV4MI_chipid3022.tiff',
#  'WY00K6L8P0_chipid2000.tiff',
#  'L15UZEVPEW_chipid2279.tiff',
#  'FE6M5I834U_chipid1585.tiff',
#  'YU7YZHSBGT_chipid2906.tiff',
#  '6M0ZHU85RE_chipid3110.tiff',
#  '3817DL29P2_chipid1342.tiff',
#  'HB2PU9C8H4_chipid1360.tiff',
#  'MC8ZRE0PMG_chipid2996.tiff',
#  '0HNZK448JN_chipid2619.tiff',
#  'XYGTGZX3KM_chipid2579.tiff',
#  '4G9950MIPU_chipid1346.tiff',
#  '2VIX97YT0T_chipid2120.tiff',
#  'AQ4LSOXY6H_chipid432.tiff',
#  'NB47SC7P2W_chipid2676.tiff',
#  'B5Q09AUKMA_chipid2377.tiff',
#  '4AHVI0BTDI_chipid2022.tiff',
#  'PB19UNK2F2_chipid1400.tiff',
#  'QBTZATZY8M_chipid265.tiff',
#  '4I8CE4MAVG_chipid1361.tiff',
#  'LOP59AAU4L_chipid1475.tiff',
#  'U29WE46KHB_chipid578.tiff',
#  '1OJ7HINJZ1_chipid56.tiff',
#  'UV10SVA0R8_chipid2184.tiff',
#  'JRSUGN84LQ_chipid409.tiff',
#  '714W6190LZ_chipid752.tiff',
#  'OGHH8GWXQS_chipid1015.tiff',
#  'O2G9DF1IN5_chipid2915.tiff',
#  'DSMCQCAGHS_chipid3264.tiff',
#  'K6N9FYLQ5O_chipid2341.tiff',
#  '2RG8REVCZI_chipid2472.tiff',
#  'OUFH1QK4P0_chipid52.tiff',
#  'J0PFWCGGH7_chipid1074.tiff',
#  'KJGB7L67JZ_chipid809.tiff',
#  '81S8ZE5JC6_chipid3164.tiff',
#  'A4Z2NV3HBT_chipid744.tiff',
#  'P7OVV2SZFT_chipid1144.tiff',
#  'YZG9CIMQRL_chipid2469.tiff',
#  '2Z59ROY3LM_chipid1755.tiff',
#  'XH5VHH13M6_chipid2270.tiff',
#  'KU5OOP0IGB_chipid33.tiff',
#  'D12KL9EQJB_chipid3091.tiff',
#  '92EB0UQH1R_chipid2806.tiff',
#  'DZT1K1M6T0_chipid441.tiff',
#  'B2VISHJJPS_chipid191.tiff',
#  '6IM9CRHNX6_chipid24.tiff',
#  '2UVG8YHBWD_chipid2663.tiff',
#  'NGBHBHZJFD_chipid1108.tiff',
#  '22GIEP6FZA_chipid616.tiff',
#  '7AA8E77E5X_chipid134.tiff',
#  '4OC5VVF7E2_chipid1843.tiff',
#  'C8ND5VUHP9_chipid1561.tiff',
#  '2LPNERFYR7_chipid2936.tiff',
#  'VV7JE7EKPP_chipid2501.tiff',
#  'T4DDL2I5W7_chipid1613.tiff',
#  'CJVK4RHCN0_chipid2355.tiff',
#  'NSQ5FX28SY_chipid567.tiff',
#  'XBJLASGPQH_chipid362.tiff',
#  'X2B401PG8U_chipid1643.tiff',
#  'Q82CF2TS6N_chipid3213.tiff',
#  'EFRZPNK5I3_chipid2093.tiff',
#  'A7AH9KHHPO_chipid2961.tiff',
#  'Q709NV7QBZ_chipid544.tiff',
#  'FXP9HAU20H_chipid110.tiff',
#  'IS9L2SSWKR_chipid1736.tiff',
#  'S6D19UIDD1_chipid1870.tiff',
#  '95ZZOND55J_chipid1942.tiff',
#  'S8CJR158G4_chipid2237.tiff',
#  '4R5QQI2BDV_chipid1775.tiff',
#  'ERY5BQ1QN9_chipid963.tiff',
#  'XT44JAGW84_chipid1838.tiff',
#  '1BH4V2SQJ3_chipid3003.tiff',
#  'GU67GM56YK_chipid2388.tiff',
#  'PJRFJSA8H1_chipid399.tiff',
#  'WVE2BN27ZB_chipid2693.tiff',
#  'NRZB4C92CL_chipid1919.tiff',
#  'OYS1TK78PJ_chipid3154.tiff',
#  'QB4O5BDWIX_chipid822.tiff',
#  'J4NL0UBUKV_chipid1049.tiff',
#  'Z662IJ86WK_chipid2595.tiff',
#  'A0KHSITPFO_chipid2991.tiff',
#  'WS37IVTBM3_chipid1852.tiff',
#  '8G660MO28X_chipid2793.tiff',
#  'L73RD07RT1_chipid1228.tiff',
#  '55CG26B3CN_chipid1773.tiff',
#  'I66HLZALVU_chipid1050.tiff',
#  'OI7041OBTU_chipid3276.tiff',
#  'MI5OABNNXA_chipid1418.tiff',
#  '9CKIYVOLDH_chipid2603.tiff',
#  'P7DYY2AT7E_chipid1980.tiff',
#  'IPFLTPZOQX_chipid1820.tiff',
#  'HEYE1UJUAY_chipid657.tiff',
#  'V8Z7TEG18D_chipid913.tiff',
#  'PT0Q84NIKE_chipid2122.tiff',
#  '8BP1ZYJL3M_chipid1495.tiff',
#  'GOLAC8PTJ4_chipid759.tiff',
#  '61G1H1XIL1_chipid585.tiff',
#  'NL974KESHQ_chipid1659.tiff',
#  'DQ7KDF735W_chipid2003.tiff',
#  'KGYWZEQP45_chipid639.tiff',
#  'XMN0EPTU1C_chipid1477.tiff',
#  'OH1YBM5Y07_chipid2411.tiff',
#  'FTID158NIP_chipid2786.tiff',
#  '17EI7MQQ42_chipid3106.tiff',
#  'Q0SOMQW8IV_chipid1123.tiff',
#  '63DEDDBWZQ_chipid2661.tiff',
#  'PU2BLSARCP_chipid631.tiff',
#  'TOOVRLRJV7_chipid819.tiff',
#  'R4L2SQS013_chipid3194.tiff',
#  '1BKQVEQS7F_chipid1303.tiff',
#  'FWYPTBKYU8_chipid1689.tiff',
#  '5VRUEZNBH7_chipid2725.tiff',
#  'JZR9QVIMG8_chipid775.tiff',
#  '0V1N6HY235_chipid1809.tiff',
#  'ZWPIRPXENS_chipid1140.tiff',
#  'NS0S5E7MZ8_chipid1751.tiff',
#  'W34IEJPTQV_chipid2715.tiff',
#  'WYX1SBZ2W4_chipid305.tiff',
#  'HXG7Q3G9AE_chipid26.tiff',
#  'C96KOHGXIY_chipid2058.tiff',
#  '5N8ABSYTOL_chipid2364.tiff',
#  'M0BS4I1PBE_chipid2743.tiff',
#  'U9T8O0N28X_chipid2726.tiff',
#  'LP6OR1RENN_chipid27.tiff',
#  '7PP0D87QL2_chipid742.tiff',
#  '1LB0P52DCZ_chipid469.tiff',
#  '0KZ2WE3F8G_chipid47.tiff',
#  'IYES4E0EBF_chipid1828.tiff',
#  'LEYNZ3WI0E_chipid2161.tiff',
#  'D9UJFV9PH3_chipid990.tiff',
#  'TD4HJ08KWC_chipid2744.tiff',
#  'C5AUBYYK58_chipid2367.tiff',
#  'WR7EUTP7M1_chipid3219.tiff',
#  'JTX766AG47_chipid374.tiff',
#  'Q0QW2E8S5X_chipid2074.tiff',
#  '4URJW1EBTX_chipid1784.tiff',
#  '7AFF6SOUC1_chipid1713.tiff',
#  'SYWHLVYKB4_chipid92.tiff',
#  '0G16CZ2OHA_chipid3281.tiff',
#  '9ULBANOBC6_chipid2884.tiff',
#  '0APPM9Y02Z_chipid41.tiff',
#  'KLYM1DUWE8_chipid203.tiff',
#  '9UQAZQG15U_chipid1791.tiff',
#  'VRKQT5CDBZ_chipid999.tiff',
#  'L39LYFAGLE_chipid604.tiff',
#  'RJ98AVEQYA_chipid2374.tiff',
#  'SCZKOQEJ2O_chipid1225.tiff',
#  'WSKY2YEQFA_chipid350.tiff',
#  '2W62YGYL37_chipid605.tiff',
#  '5WBBNWGMR9_chipid2775.tiff',
#  'APYSIER1J5_chipid2834.tiff',
#  'IS8OQ3AAMI_chipid413.tiff',
#  'F5AYSF13PF_chipid2746.tiff',
#  'GGT9E2AMQL_chipid221.tiff',
#  'CZIIJ2B24E_chipid589.tiff',
#  'TKX4VBWB76_chipid2989.tiff',
#  '250AQXBSVA_chipid2287.tiff',
#  'Z7XZBA9YME_chipid2632.tiff',
#  'MSQEO3U41U_chipid382.tiff',
#  'F2ZN58AT6E_chipid2904.tiff',
#  'RBJUBTEJN9_chipid1904.tiff',
#  'GUSUK4LI2H_chipid1093.tiff',
#  'BVGNQ2BXE7_chipid1819.tiff',
#  'UYQARQ8RBS_chipid1536.tiff',
#  'F715U9TO5O_chipid240.tiff',
#  'OW4ZB6B18X_chipid2199.tiff',
#  'D730XUAIIU_chipid517.tiff',
#  'DGTVD1V1DI_chipid3021.tiff',
#  'RVOESS3INR_chipid597.tiff',
#  'OIFLD2MDEH_chipid2953.tiff',
#  'H6ZP8DJ0WI_chipid630.tiff',
#  'GF5DN7RW0B_chipid2815.tiff',
#  'B14HR2PDE0_chipid2244.tiff',
#  'I9R6WY0L5O_chipid2836.tiff',
#  '92SD1EZGYO_chipid1112.tiff',
#  '51BSPVW30J_chipid2415.tiff',
#  'UFKLDN3VHU_chipid3239.tiff',
#  'Z6TF3ODV94_chipid2444.tiff',
#  'GAKJOZ5A8H_chipid1466.tiff',
#  '7W0GM9PPU0_chipid2340.tiff',
#  'DT27KYJ0R4_chipid2940.tiff',
#  'AFE3GCL27X_chipid3217.tiff',
#  'LBWWABPPJN_chipid1385.tiff',
#  'HY0RQQKWJY_chipid3187.tiff',
#  '2CAHY0OCMI_chipid383.tiff',
#  'PZ78FPSFW6_chipid2168.tiff',
#  'VSCLSHTES3_chipid916.tiff',
#  'HZORVX4F89_chipid2092.tiff',
#  'PD7SJNFLNL_chipid593.tiff',
#  'ILQDFOBNL9_chipid1268.tiff',
#  '1YGQXE5M5F_chipid1687.tiff',
#  'SFRBZ0Y4TP_chipid3171.tiff',
#  'VC6YV9PVT6_chipid2696.tiff',
#  '9KJMQA4J70_chipid1294.tiff',
#  '6UK57DW78E_chipid872.tiff',
#  'YJ60YM4OOW_chipid1515.tiff',
#  '430YQ8L34C_chipid533.tiff',
#  'ADJ05XXNNI_chipid419.tiff',
#  '806CE8CPBE_chipid1670.tiff',
#  'P3RPBX162Z_chipid320.tiff',
#  'ZKD55UQCI7_chipid1345.tiff',
#  'A3IA6FACKF_chipid2959.tiff',
#  'SJIY53OB2V_chipid2020.tiff',
#  '188FORPBDT_chipid2381.tiff',
#  'S3RXBREIO9_chipid3121.tiff',
#  'HRNV1E07CN_chipid1983.tiff',
#  '1O2TUSNL34_chipid2736.tiff',
#  'BBH8RFWE05_chipid1420.tiff',
#  'M6Y2TJXFX7_chipid2183.tiff',
#  'R8X26QGX1Y_chipid2969.tiff',
#  'ER4M7LDHN8_chipid851.tiff',
#  '2EELP5PMC2_chipid241.tiff',
#  'P0BU7LXM3C_chipid1664.tiff',
#  'W9CBS03DIA_chipid3097.tiff',
#  'M1199WF9KK_chipid2098.tiff',
#  'JUJOXMTI8Q_chipid2379.tiff',
#  '5KJHYGJTFW_chipid609.tiff',
#  'L7WDWYE9OZ_chipid2274.tiff',
#  'YMYSQ0VDTG_chipid1992.tiff',
#  '62YTQRVQM4_chipid2354.tiff',
#  'DL8S8JH0YH_chipid475.tiff',
#  'E3APYG0DN6_chipid34.tiff',
#  'KOUDL1LQ8D_chipid2380.tiff',
#  'INXCS57J2W_chipid1364.tiff',
#  '928FG5O0QI_chipid2758.tiff',
#  'CGWUIOQVU4_chipid335.tiff',
#  'YCDLGWY7RL_chipid1350.tiff',
#  '7KB2BAHW5N_chipid1831.tiff',
#  '0PJBU41AQD_chipid315.tiff',
#  'PCYSF2J0DO_chipid1261.tiff',
#  'DXCEJV6X8I_chipid172.tiff',
#  '3MPCYNM0L8_chipid298.tiff',
#  'J9H0VL64RZ_chipid2495.tiff',
#  'P6W7W9K2U5_chipid2094.tiff',
#  'LY6XS3ZLN2_chipid2192.tiff',
#  'MZDRUBS9RF_chipid602.tiff',
#  'D7KZKKNBCK_chipid2001.tiff',
#  'P26O2COMHS_chipid3101.tiff',
#  'YRKVM6BVRX_chipid1963.tiff',
#  'RJ887FC78G_chipid2082.tiff',
#  '8RYL8962S6_chipid951.tiff',
#  'N0SIKR03D2_chipid550.tiff',
#  'IPUD4OD4GC_chipid2842.tiff',
#  'BK5U1ZPNV2_chipid1930.tiff',
#  'HWQ8TL4UUY_chipid1181.tiff',
#  'IAKWPNDI20_chipid3087.tiff',
#  'HLA40USG92_chipid608.tiff',
#  'BW5K7DBNCX_chipid1560.tiff',
#  'QTDOAS8D3H_chipid1790.tiff',
#  'QPBCMZ8TTT_chipid384.tiff',
#  'A7ZALHP0SX_chipid1410.tiff',
#  'E0REZHY2FB_chipid2431.tiff',
#  '0KVYTDBB9E_chipid2841.tiff',
#  '8PDKZP07P3_chipid1910.tiff',
#  '4OM5IHECH7_chipid1076.tiff',
#  'MQS87HEUMX_chipid197.tiff',
#  'LM5QBMQRMV_chipid3231.tiff',
#  'DISFH0ZF2H_chipid1157.tiff',
#  '3W9OI4OPQY_chipid586.tiff',
#  'KC2Z5ZG8VP_chipid1230.tiff',
#  '2VS422BVWR_chipid2516.tiff',
#  'AFLIFIDHC1_chipid2324.tiff',
#  'BBJR3ZKE8J_chipid1323.tiff',
#  'Q3ELR7655B_chipid918.tiff',
#  '5NJHVJWYQ0_chipid1552.tiff',
#  'ZW57TM0DL8_chipid2755.tiff',
#  'F2F6MDDVF4_chipid2617.tiff',
#  'L412T6JWWE_chipid496.tiff',
#  'LXPD51H1HY_chipid1287.tiff',
#  '6UVVFBC2FQ_chipid2945.tiff',
#  'O7AMUMX4OL_chipid2545.tiff',
#  'R9IQZCNHKT_chipid2641.tiff',
#  'XQTH77SACN_chipid2889.tiff',
#  '9SC9ABCG8W_chipid1628.tiff',
#  'P68S60QS37_chipid1559.tiff',
#  'LZ3SSZFEIA_chipid260.tiff',
#  'OK8HTNWO64_chipid1434.tiff',
#  'MD06971KOB_chipid1190.tiff',
#  'T4WU1DPASP_chipid2478.tiff',
#  'NRCY7N5IRB_chipid2648.tiff',
#  'C1BCMVBH7A_chipid2254.tiff',
#  'XLISTIM2YM_chipid1007.tiff',
#  'D1L6E51Q1T_chipid1.tiff',
#  'LHK1XOBEBH_chipid652.tiff',
#  'DSO5EJJ4MW_chipid2597.tiff',
#  'IV3F9S5AVN_chipid1482.tiff',
#  '9DRHG4EE86_chipid687.tiff',
#  '7QS8KEZYV8_chipid252.tiff',
#  'JVXX69VE36_chipid920.tiff',
#  'FR2DPL9W0M_chipid1977.tiff',
#  'K8605603BC_chipid833.tiff',
#  'YAZXAB19I8_chipid2894.tiff',
#  'GQ0G83S947_chipid858.tiff',
#  'PJR5EI6T8X_chipid1396.tiff',
#  'KOZMIT3QJ4_chipid1064.tiff',
#  'PB14Y6M8B9_chipid1947.tiff',
#  '613CMABP5J_chipid1141.tiff',
#  'D65EBV0ZYT_chipid816.tiff',
#  '31VALPJDUS_chipid1097.tiff',
#  'W1Y54DTD2J_chipid217.tiff',
#  'FMQIQ4PKBQ_chipid1575.tiff',
#  '4XBZ8GC0KJ_chipid3138.tiff',
#  'X4K2GV0USJ_chipid863.tiff',
#  'RTPWMDJRDL_chipid2562.tiff',
#  'RFZPTIVV9K_chipid1899.tiff',
#  'GZNRAKR8Q5_chipid3130.tiff',
#  'RNLRXGGCIN_chipid1059.tiff',
#  'M3JRTETNZZ_chipid2385.tiff',
#  '8XDQN6VMAC_chipid2006.tiff',
#  'DJ39YTGCNF_chipid1533.tiff',
#  'DJRQMEZA0C_chipid2077.tiff',
#  '2FB8W6LJ58_chipid2104.tiff',
#  'VB8LGU6B1P_chipid1717.tiff',
#  'BX5OAVDWSF_chipid1869.tiff',
#  'C27GPV5AF6_chipid1788.tiff',
#  'N0XNZWYJZP_chipid3048.tiff',
#  'UACJYBLXXV_chipid2138.tiff',
#  'YOFKXI6WKB_chipid16.tiff',
#  '56WMQVPMZM_chipid556.tiff',
#  '3T5HWNG3RA_chipid2032.tiff',
#  '4NKOPLD3TJ_chipid538.tiff',
#  'XU2VR8I3N9_chipid244.tiff',
#  '7YGG12FPMG_chipid874.tiff',
#  'J3J44D63O9_chipid2827.tiff',
#  '1Y6OL6G9ZV_chipid1060.tiff',
#  'YPRULBO7UO_chipid1938.tiff',
#  'LC2T5YX051_chipid698.tiff',
#  'QTFU3W5WHZ_chipid2534.tiff',
#  'W54AU6AJ2F_chipid673.tiff',
#  '00229MWOCA_chipid215.tiff',
#  'UTUYQOU2NR_chipid1255.tiff',
#  '7FDJH53PPQ_chipid2417.tiff',
#  'PJOUMD1TGJ_chipid2774.tiff',
#  'CBNJRP6H1N_chipid139.tiff',
#  'YI49AUPB24_chipid2585.tiff',
#  'U1X3D8XG7W_chipid2723.tiff',
#  '6PLWJA53FB_chipid1556.tiff',
#  'RAEIJG2B32_chipid466.tiff',
#  'O2WN7YH1YD_chipid302.tiff',
#  'UOL8EIRL0L_chipid1272.tiff',
#  'WXFO5DEF2Z_chipid1932.tiff',
#  'PZY2ZMYCDY_chipid2883.tiff',
#  '5XBNSL6AAI_chipid2800.tiff',
#  '0OCZUSBXZU_chipid1622.tiff',
#  'SS90M2X12R_chipid1426.tiff',
#  'AK69E4EDHX_chipid509.tiff',
#  'LQJA9CD19N_chipid206.tiff',
#  'UTTWPRFHJV_chipid358.tiff',
#  'AZFY7CZPTJ_chipid12.tiff',
#  '2XCE18QB78_chipid68.tiff',
#  'QGGK1AP47D_chipid1019.tiff',
#  'PE2CRBC34Z_chipid777.tiff',
#  'DVTWUDWYUJ_chipid369.tiff',
#  '4SI5ZN3WW6_chipid1990.tiff',
#  'JE7QK0PKYE_chipid90.tiff',
#  '05R8EEDS8O_chipid1134.tiff',
#  'S1HOXKL6FL_chipid1161.tiff',
#  'RS1T6GNQR0_chipid486.tiff',
#  'G5C89QQRH8_chipid1549.tiff',
#  'ZYKFGW1YBE_chipid704.tiff',
#  'E0BNBDSUYL_chipid2909.tiff',
#  'S4GI1Y5EZM_chipid628.tiff',
#  '1H1OSBW5EC_chipid1393.tiff',
#  'IY6QGM0VL0_chipid537.tiff',
#  'PSTUOQ3LFG_chipid2742.tiff',
#  'FETT4MLCCN_chipid159.tiff',
#  'PM31Q4TNPQ_chipid1906.tiff',
#  'MCNFWHK6S5_chipid3128.tiff',
#  'PJIYD7N88U_chipid703.tiff',
#  'SL60K2ZQJI_chipid1090.tiff',
#  'HP5O8FNH4X_chipid151.tiff',
#  'T6G1F0S176_chipid253.tiff',
#  'GPZ6DF5SRV_chipid827.tiff',
#  'UDMW9H62SR_chipid3192.tiff',
#  'MKZRV97DS4_chipid2738.tiff',
#  '8DTNJYDCAK_chipid2964.tiff',
#  'DR52QO9ERQ_chipid1155.tiff',
#  'ZET9MHBIEL_chipid138.tiff',
#  'AH0X6Z6Z5I_chipid2263.tiff',
#  'AZSHNXZUN6_chipid2456.tiff',
#  'D0NLYTF5YP_chipid2863.tiff',
#  '0TDUWHPADE_chipid1654.tiff',
#  'L0OFEITJXO_chipid1078.tiff',
#  'CPWCFD98Q9_chipid2297.tiff',
#  'O55DDV996A_chipid3126.tiff',
#  'E0B8H6GDEY_chipid1308.tiff',
#  'CU0IOZ49XI_chipid3027.tiff',
#  '3OAMFM4YFF_chipid1044.tiff',
#  'HOXE8J4BJH_chipid1600.tiff',
#  'PUY9SMHOCZ_chipid440.tiff',
#  '08J9EMBD11_chipid1502.tiff',
#  '7225HI6GM6_chipid641.tiff',
#  'RLLQ34DL0G_chipid1321.tiff',
#  'HF07W4MPQ6_chipid2257.tiff',
#  'TF4IGWARIE_chipid508.tiff',
#  'B35364G17H_chipid1534.tiff',
#  '6GL11029SP_chipid1389.tiff',
#  'R70HD547AL_chipid1331.tiff',
#  'XLYKU8M96Y_chipid98.tiff',
#  'DY762SC1LA_chipid2546.tiff',
#  '4J6HPDLCA2_chipid3243.tiff',
#  'HQA55BEEBK_chipid1681.tiff',
#  'JX1S7VUPIA_chipid692.tiff',
#  'QIPOKVZEJA_chipid3114.tiff',
#  '252MYKM8ZB_chipid1514.tiff',
#  'DFQCDXQAWR_chipid2445.tiff',
#  '8KEPAF7FLN_chipid2946.tiff',
#  'HXCX1QX5H5_chipid1460.tiff',
#  'MAR8DUS95C_chipid3204.tiff',
#  'LETTXO3K9X_chipid546.tiff',
#  'Y8W7V4I96S_chipid2967.tiff',
#  'BRB047KNDL_chipid3172.tiff',
#  '0736LX2ZIF_chipid2670.tiff',
#  '8NW5OQ9AC8_chipid1550.tiff',
#  'EWS1MJOP5S_chipid160.tiff',
#  'Z3HBVRGTZ3_chipid949.tiff',
#  'S7S2R9BWMO_chipid2465.tiff',
#  '09RC4JE2LD_chipid1384.tiff',
#  'O03IWPAM5Q_chipid1328.tiff',
#  '250UW8EMME_chipid2552.tiff',
#  '8L7VWI6QGU_chipid2373.tiff',
#  'LQR0SKR9UT_chipid735.tiff',
#  'Z2D7WDRAQU_chipid2314.tiff',
#  '710BHYZC1G_chipid79.tiff',
#  '4DC5KGK7L7_chipid3174.tiff',
#  'XR0RYROSGW_chipid2561.tiff',
#  'UO5JCDVGSZ_chipid3144.tiff',
#  'B28SPVSSZB_chipid1528.tiff',
#  'MJNXLT70LD_chipid1696.tiff',
#  'SIP2QPMOAZ_chipid1532.tiff',
#  'MYIOJ2HGFZ_chipid2046.tiff',
#  'XL4OUGYN5I_chipid2882.tiff',
#  'T33A1FBNXS_chipid3009.tiff',
#  'OAFKFR7B7J_chipid1334.tiff',
#  'N1IPYFB4NV_chipid1856.tiff',
#  '8109QS0E4K_chipid2707.tiff',
#  '25KRL7PLX8_chipid1762.tiff',
#  'AOYYOD9V83_chipid564.tiff',
#  'VQBDI7Y2XS_chipid2132.tiff',
#  'Y2W45A1YN8_chipid2419.tiff',
#  'ID9BV5QDCW_chipid2757.tiff',
#  '22W91ZRZOJ_chipid2649.tiff',
#  'PWV3GEDZA8_chipid1247.tiff',
#  'C6WEPL3AGP_chipid1513.tiff',
#  'F54GWWV0SA_chipid2831.tiff',
#  '1SDQI5OB59_chipid973.tiff',
#  'ZLMZTEO7UZ_chipid77.tiff',
#  'A1CNLG1R72_chipid1952.tiff',
#  'H4IB6F329A_chipid2276.tiff',
#  '2C9ULHV4UN_chipid2869.tiff',
#  'AVGPSQIW3A_chipid1595.tiff',
#  'FAKI9G37XF_chipid2105.tiff',
#  'IQT965XCXY_chipid1392.tiff',
#  'G4K4E5WOJK_chipid2816.tiff',
#  'UH9QTO95O6_chipid1080.tiff',
#  'Y1GACF9QI0_chipid2223.tiff',
#  'NL446KQZEC_chipid2459.tiff',
#  'A3V9YAG19Q_chipid264.tiff',
#  '8KGK2B9OUV_chipid563.tiff',
#  '9NWM2WA7HA_chipid730.tiff',
#  '0S78TXR5LR_chipid655.tiff',
#  'Z0EFTBFSMS_chipid2277.tiff',
#  '8B4ISN7RAG_chipid489.tiff',
#  '95BFFL6SOT_chipid1424.tiff',
#  'BCMRFRA8XA_chipid621.tiff',
#  '8ADSYY2WX3_chipid2822.tiff',
#  'BJVS3FF2KV_chipid431.tiff',
#  '2PJ2LJHO6O_chipid2847.tiff',
#  '2I5IQHH311_chipid3156.tiff',
#  'EHGFFJV0MV_chipid2902.tiff',
#  'N4S4ZVXTGI_chipid2540.tiff',
#  '9N1K30DIET_chipid1435.tiff',
#  '9U1PNQ55E7_chipid1244.tiff',
#  'Z4YXJQU2FC_chipid461.tiff',
#  'CCO02R4VHX_chipid527.tiff',
#  'JXJN98TLO8_chipid2468.tiff',
#  'IRYK23ZNHV_chipid232.tiff',
#  'RSYEX9YIRH_chipid153.tiff',
#  'PUVQG6HHG6_chipid1812.tiff',
#  'JR2R8SMVUX_chipid2450.tiff',
#  'IIZ12E76C6_chipid1009.tiff',
#  'EQOWHBKU3O_chipid2382.tiff',
#  '8W5R1H8ZQJ_chipid1053.tiff',
#  'C0Y186TPQW_chipid1235.tiff',
#  'L7XBV25IQZ_chipid3036.tiff',
#  '0RDJ64WOPX_chipid1300.tiff',
#  'WTP1QBQBB8_chipid549.tiff',
#  'GDSF32HS11_chipid1578.tiff',
#  'LOKWHU4VTV_chipid2851.tiff',
#  'L8Q0AJ5IJ0_chipid137.tiff',
#  'HT36IN225K_chipid2264.tiff',
#  'QIKTDGL889_chipid2767.tiff',
#  'EH74EVT63N_chipid2527.tiff',
#  '3J9O901WYF_chipid1476.tiff',
#  'ANL2FTAJR9_chipid2217.tiff',
#  'GVD2W18BJ9_chipid843.tiff',
#  'E1WX22ECHF_chipid97.tiff',
#  'KGA2ZR5VPM_chipid1267.tiff',
#  'IRY0OG03XL_chipid678.tiff',
#  '8OIWZXMRNY_chipid3090.tiff',
#  '35AWF4U5O5_chipid1023.tiff',
#  'YI5L7DDNQZ_chipid2845.tiff',
#  '7UFIU1JD5P_chipid964.tiff',
#  'XTR8JNHPF2_chipid1606.tiff',
#  'ZXNIZYHN2T_chipid915.tiff',
#  '4TVFUOHWA4_chipid3123.tiff',
#  '7BOQFB47M5_chipid2714.tiff',
#  'IUS7JEB61X_chipid875.tiff',
#  'YDRTCKX54A_chipid2038.tiff',
#  'VDWY4SWMD5_chipid2797.tiff',
#  'OXB32D2Q3J_chipid1191.tiff',
#  '28CISV7ERY_chipid2997.tiff',
#  'EO461R45A6_chipid659.tiff',
#  'LWJDO8OMEG_chipid1242.tiff',
#  'IGTCIV30QT_chipid529.tiff',
#  '29C07NGF8B_chipid1530.tiff',
#  '6YFBGU181D_chipid328.tiff',
#  'R9Y3AVKZXF_chipid1619.tiff',
#  'MLHU1Q4J7T_chipid1882.tiff',
#  'IKCVQ5NHGG_chipid2177.tiff',
#  'SPRP59IYGW_chipid3111.tiff',
#  '0R3EK80OM1_chipid225.tiff',
#  'UMSJBYD8TX_chipid2011.tiff',
#  '333M1X8FU4_chipid50.tiff',
#  'K59BX9CLCN_chipid2995.tiff',
#  '0ERWHQ1RVJ_chipid2897.tiff',
#  'ZBMI3N6EWJ_chipid19.tiff',
#  'J1YD0KTPM0_chipid1916.tiff',
#  'MOAWI77B6W_chipid2630.tiff',
#  '4NXV74GMBK_chipid1220.tiff',
#  'CEO63RBQV0_chipid2404.tiff',
#  'YM1E3PF4E3_chipid3262.tiff',
#  'XBB4KM9L7I_chipid741.tiff',
#  '2XSZOJ2ENL_chipid2305.tiff',
#  '8D68PE3T12_chipid1782.tiff',
#  'IWMHXZAG5P_chipid65.tiff',
#  '5XNAVHWO29_chipid154.tiff',
#  'V1WJQUB2QH_chipid2640.tiff',
#  '6LLJ4DWYUV_chipid1028.tiff',
#  '2N8OP1AI3L_chipid6.tiff',
#  'FWXJWGDEL8_chipid505.tiff',
#  'MFE1OWYJ93_chipid1262.tiff',
#  'XHLZ5115LM_chipid3257.tiff',
#  'V11C050T61_chipid2283.tiff',
#  'IWUX6OB3WU_chipid2671.tiff',
#  'SBNJG3PEX7_chipid356.tiff',
#  'CH8EZU4SLK_chipid412.tiff',
#  'BTHFU9HO0D_chipid422.tiff',
#  'PKAFIQKTCB_chipid1988.tiff',
#  'RWTQ6BGR17_chipid442.tiff',
#  'A477UNMT0G_chipid373.tiff',
#  '71DVQN9GOY_chipid598.tiff',
#  'L89WGI7QUJ_chipid1118.tiff',
#  '8YBI2OR1LH_chipid2887.tiff',
#  'A4EJFX6W0X_chipid2986.tiff',
#  'GXYG98DVMB_chipid762.tiff',
#  '7KDDDA2VMP_chipid988.tiff',
#  'AP481CXAD9_chipid208.tiff',
#  'PNWA68Y6BM_chipid2917.tiff',
#  '5RQ02J9XWN_chipid1707.tiff',
#  'HW95DZTK3P_chipid989.tiff',
#  'MNSZXZ50RO_chipid371.tiff',
#  'V0I0H839OV_chipid2024.tiff',
#  'IA9JAK1FZ2_chipid968.tiff',
#  'VWFYWXK4F0_chipid3278.tiff',
#  'UY7UM2QK8R_chipid1315.tiff',
#  'TT2GJ4DDC1_chipid1081.tiff',
#  'WZPYLIC0RA_chipid719.tiff',
#  '1D6YKYTQIE_chipid2342.tiff',
#  'NHDTXK9WUR_chipid1577.tiff',
#  '6QMKKNHJC7_chipid1057.tiff',
#  'RMP0GJ3TW1_chipid453.tiff',
#  '99FNG4KU7K_chipid2704.tiff',
#  '0VCOTMTC3B_chipid59.tiff',
#  '8AOXMN0GVE_chipid1785.tiff',
#  'LRTFZQLP2D_chipid2716.tiff',
#  'T4Y7ML3XK9_chipid653.tiff',
#  'IZ6G2MMCQ2_chipid2025.tiff',
#  'CANX0UGLP3_chipid2143.tiff',
#  'L0XJRNRHDT_chipid710.tiff',
#  '3QLNLMKJN9_chipid2203.tiff',
#  '9RWBJNMLTC_chipid2066.tiff',
#  '32KTJ2A9UP_chipid2652.tiff',
#  '611E7AT1SX_chipid1866.tiff',
#  '5SZFXM4LZO_chipid3136.tiff',
#  '3XLHDACZI1_chipid2320.tiff',
#  'OMBAHSO2B8_chipid237.tiff',
#  'PS4HXGR0KU_chipid3282.tiff',
#  'RSUOIHLZM8_chipid2624.tiff',
#  '1MJVYN1CKC_chipid121.tiff',
#  'XUY41YE9MN_chipid2406.tiff',
#  'C5I1WGPCCA_chipid1504.tiff',
#  'JNXXKDTYUS_chipid2789.tiff',
#  'NAMKR1E8C4_chipid781.tiff',
#  'WEMUL9POO8_chipid2302.tiff',
#  'PINMU19B3E_chipid2541.tiff',
#  'TDOD5UCBYZ_chipid835.tiff',
#  'FMOBQ68WTH_chipid1343.tiff',
#  'EVD9BZZEOY_chipid871.tiff',
#  'GV8DM1IZMW_chipid2766.tiff',
#  '7ZNBC4G7X6_chipid1168.tiff',
#  '4B7WE4Q8HB_chipid1496.tiff',
#  'UP3Y6TVFHG_chipid2009.tiff',
#  'EKUT0BOO9N_chipid1248.tiff',
#  'U742GDSJRI_chipid786.tiff',
#  'MTYGAANST5_chipid1845.tiff',
#  'FVPZU31T9W_chipid2248.tiff',
#  'ED6F3YTA79_chipid23.tiff',
#  'BDO238R3KO_chipid229.tiff',
#  '0YOZULUKC0_chipid942.tiff',
#  'BHYZEE1WOC_chipid1271.tiff',
#  'MGX0C1P2FJ_chipid2776.tiff',
#  '6Q1XYS4FNU_chipid2155.tiff',
#  'F4RMLJY230_chipid3065.tiff',
#  'NPLRGFXNIT_chipid3240.tiff',
#  'LR4CFW8I4F_chipid2485.tiff',
#  '9IM5QW5GQO_chipid3062.tiff',
#  'B0ZGPNXJN1_chipid1839.tiff',
#  'RKVL1YP54X_chipid2486.tiff',
#  'E425SJA97A_chipid381.tiff',
#  'QMK1YO8OPW_chipid345.tiff',
#  'JETMMG4A7K_chipid1459.tiff',
#  'PED0XU9XMD_chipid250.tiff',
#  '4K1ONZSMV8_chipid709.tiff',
#  'WJFV1X4662_chipid2550.tiff',
#  '84N0BLEM6J_chipid2064.tiff',
#  '2FLB6D0YAQ_chipid1800.tiff',
#  'EEOR8ECCDH_chipid2175.tiff',
#  'VMDJL899IY_chipid2717.tiff',
#  'O14IF8O45A_chipid1320.tiff',
#  'DP312K7ZN5_chipid3116.tiff',
#  '027RKUYPGJ_chipid1359.tiff',
#  'YDL4QJT6Y3_chipid391.tiff',
#  '9M9IFSUR9V_chipid1517.tiff',
#  'ZFOOWAIADC_chipid1623.tiff',
#  'WCZB0PAGPA_chipid2892.tiff',
#  'IZ9EPUJU55_chipid2633.tiff',
#  'LGU0RF8W05_chipid2988.tiff',
#  'RFJ0YISM46_chipid860.tiff',
#  '3MRVHZYVFF_chipid625.tiff',
#  'ZP275SOV20_chipid2830.tiff',
#  'DDVQN37D98_chipid3186.tiff',
#  '9ZXFIO6FGE_chipid675.tiff',
#  '1T1QYF84R1_chipid2983.tiff',
#  'GNHT837M9S_chipid2777.tiff',
#  '2O0E98Q936_chipid3109.tiff',
#  'LUV0YKY8GE_chipid3267.tiff',
#  'NH7X4D0QF1_chipid754.tiff',
#  'I2JIBGTK65_chipid2473.tiff',
#  'ACZI208FMD_chipid2494.tiff',
#  '3RRCPWHK3Q_chipid2181.tiff',
#  'GDULJH19ME_chipid2645.tiff',
#  'BGA1YHIEMF_chipid2481.tiff',
#  '354ZKIN93B_chipid1594.tiff',
#  'RETJPWLEOD_chipid3246.tiff',
#  '8GFI0SI25Q_chipid3031.tiff',
#  'STV18LPCDU_chipid2974.tiff',
#  '9U8WKEM0YG_chipid1370.tiff',
#  '06TMTJCXOH_chipid1082.tiff',
#  'IYRI6HZ8L8_chipid2745.tiff',
#  'V57XG2WRWP_chipid1394.tiff',
#  'RG5XNVZJP5_chipid1450.tiff',
#  '17EJ9G878N_chipid2369.tiff',
#  'GE73F783C1_chipid2033.tiff',
#  'L1OGJTOEAE_chipid623.tiff',
#  'FFF5MI5MIX_chipid213.tiff',
#  '6TA07EP116_chipid2665.tiff',
#  '62H42IWZLN_chipid20.tiff',
#  'RA1C0HCT71_chipid1016.tiff',
#  '907K12LF21_chipid3203.tiff',
#  'H5NTGUK9PT_chipid1088.tiff',
#  'BX8Q4R31VQ_chipid522.tiff',
#  'EP5DX836F5_chipid2278.tiff',
#  '9FLUPXU34A_chipid842.tiff',
#  'Z1XHVYY8FK_chipid1042.tiff',
#  '4DOCSXXPZJ_chipid2504.tiff',
#  'HAB0LNTAA2_chipid3139.tiff',
#  'Z6B3NS9JYU_chipid3252.tiff',
#  'O3I9H39OPT_chipid491.tiff',
#  'N7Z01V3FXB_chipid2229.tiff',
#  '7D0E10W9Q0_chipid1203.tiff',
#  'KYWPY0SYGG_chipid3113.tiff',
#  'HOW58Z6R6Y_chipid3071.tiff',
#  'QE52ZB373J_chipid3230.tiff',
#  'UDB094VJIJ_chipid1493.tiff',
#  '9X70MOH8X2_chipid3058.tiff',
#  'XOLCN4OJ4J_chipid2500.tiff',
#  'YX8OYJFK7M_chipid3046.tiff',
#  'A9A1RPK3IZ_chipid1880.tiff',
#  'BR5979WM2T_chipid474.tiff',
#  'XYKA7SLAPO_chipid182.tiff',
#  'R1HDT3I494_chipid402.tiff',
#  'I3AQ9DH6VF_chipid1739.tiff',
#  'LHDJWV5JX2_chipid718.tiff',
#  'EU7VDDHCRF_chipid2350.tiff',
#  'ANKTDS5AMK_chipid1607.tiff',
#  'VVH7EBTH86_chipid1172.tiff',
#  'LO3XXQDWB7_chipid2878.tiff',
#  'MC9WEU7BOB_chipid2885.tiff',
#  'ND02F4O6F6_chipid1127.tiff',
#  'RQCRQCGOIZ_chipid2196.tiff',
#  'IMHXQSKJAK_chipid2998.tiff',
#  '4DAMDGI2H5_chipid1039.tiff',
#  'YYW96LES9T_chipid1085.tiff',
#  'Z731SVIGNE_chipid3195.tiff',
#  'ZCU4FW6674_chipid3184.tiff',
#  'JRUXBWB879_chipid984.tiff',
#  'NK92IZKZ50_chipid1898.tiff',
#  'ULERFZ7ZPZ_chipid268.tiff',
#  'GNS9F85DBO_chipid1237.tiff',
#  'UY1JJCCU41_chipid3112.tiff',
#  'NIMZ981NEK_chipid1333.tiff',
#  'RT4WTPKF1Q_chipid3233.tiff',
#  '554092D4B9_chipid1025.tiff',
#  'BZGPBWBODH_chipid1457.tiff',
#  'N7A6KMDACY_chipid1954.tiff',
#  'QAD8RV6DWD_chipid944.tiff',
#  '62V2P67O0C_chipid1474.tiff',
#  '7SPNMYZFIW_chipid1511.tiff',
#  '6E4M51NZPT_chipid2625.tiff',
#  '55JU12KPF0_chipid2683.tiff',
#  'L40ULVRGXZ_chipid3014.tiff',
#  'SCJJI15B26_chipid2071.tiff',
#  '7A1MRHKHYO_chipid2449.tiff',
#  'M2MBKPHS6M_chipid1406.tiff',
#  'NV5KS3W928_chipid669.tiff',
#  'B8MIONVQGM_chipid1317.tiff',
#  'IK59D3UEST_chipid784.tiff',
#  'QXH4V0OIUO_chipid2490.tiff',
#  'IJKWUYU7TF_chipid309.tiff',
#  '7WU8DJYFSP_chipid448.tiff',
#  'MPPY8RWFBJ_chipid2359.tiff',
#  'YLEA413W84_chipid1901.tiff',
#  '0RVXEWX541_chipid1921.tiff',
#  '8VYXFEPIAN_chipid607.tiff',
#  '64VB9GV5WX_chipid3108.tiff',
#  'MWRU9Q1935_chipid82.tiff',
#  'FEHIVO5F2D_chipid377.tiff',
#  'GXXSYJW8EH_chipid515.tiff',
#  '8L1XW5HBWB_chipid1349.tiff',
#  'NUO2C474V8_chipid3155.tiff',
#  '3PQU6LWXMG_chipid2616.tiff',
#  'XCA7Q153HR_chipid536.tiff',
#  'KQV1GGAGII_chipid2929.tiff',
#  '376H8AKOW8_chipid2440.tiff',
#  'J6UBBOLLIM_chipid1886.tiff',
#  'AL2OPWLQGG_chipid3068.tiff',
#  'MK4RIASFJH_chipid429.tiff',
#  'JOCPHL6A04_chipid76.tiff',
#  ...]

# %%
! mkdir broken

# %%
# !mv /Users/siddharthsachdeva/repos/agroforestry/notebooks/exploration/data/filteredtiffs/Goa/3d66a1c8-d2cd-4c82-91b4-411897db3329/ broken/

# %%
# !mkdir /Users/siddharthsachdeva/Downloads/punjab_skysatimages/

# %%
def get_region(shape, key, point):
    for row_id, row in shape.iterrows():
        if row['geometry'].intersects(point):
            return row[key]
        
    return 'unknown'

# %%
wanted_remaining = {
    'NORTH EAST TRANSITION': 800,
    'NORTH EAST DRY': 516,
    'NORTHERN DRY': 192,
    'CENTRAL DRY': 0,
    'EASTERN DRY': 0,
    'SOUTHERN DRY': 450,
    'SOUTHERN TRANSITION': 0,
    'WESTERN TRANSITION': 508,
    'HILL': 760,
    'COASTAL': 538
}

# %%
shp_file = '../karnataka_footprints/DISTRICT_BOUNDARY.shp'
data = gpd.read_file(shp_file).to_crs(32643)
data = data[data['STATE'] == 'KARN>TAKA']

district_to_zone = {
    'SHIVAMOGGA': 'SOUTHERN TRANSITION', 
    'UTTARA  KANNADA': 'HILL', 
    'D>VANGERE': 'CENTRAL DRY', 
    'CHITRADURGA': 'CENTRAL DRY', 
    'BALL>RI': 'NORTH EAST DRY', 
    'DH>RWAD': 'WESTERN TRANSITION', 
    'GADAG': 'NORTHERN DRY', 
    'KOPPAL': 'NORTH EAST DRY', 
    'R>ICH@R': 'NORTH EAST DRY',
    'Y>DG|R': 'NORTH EAST DRY', 
    'KODAGU': 'SOUTHERN DRY', 
    'MANDYA': 'SOUTHERN DRY', 
    'R>MANAGARAM': 'EASTERN DRY', 
    'DAKSHINA  KANNADA': 'COASTAL', 
    'HASSAN': 'SOUTHERN TRANSITION', 
    'KOLAR': 'EASTERN DRY', 
    'BENGAL@RU RURAL': 'EASTERN DRY', 
    'UDUPI': 'COASTAL', 
    'TUMAK@RU': 'CENTRAL DRY', 
    'CHIK BALL>PUR': 'EASTERN DRY',
    'unknown': 'None'
}

# %%
from PIL import Image
import torch
import random
import string
import rasterio

for i in range(1):
    os.makedirs(f'./extra_karnataka/', exist_ok=True)

torch.manual_seed(3)
sampler = GridGeoSampler(dataset, size=400, stride=400)
dataloader = DataLoader(dataset, sampler=sampler, collate_fn=stack_samples)
c = 0
for i, batch in enumerate(dataloader):
    unbinded = unbind_samples(batch)
    sample = unbinded[0]
    im = sample['image']
#     print(sample.keys())
    rand_str = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(10))
    numpixels = im.shape[0] * im.shape[1] * im.shape[2]
    numzero = (im == 0).sum().item()
    ratio = numzero / numpixels
    if ratio < 0.2:
# Reorder and rescale the image
        image = sample["image"][[0,1,2]].numpy().astype('uint8')
#         im = Image.fromarray(image)
        # bin = int(random.random() * 2)+7
        p = f'./extra_karnataka/{rand_str}_chipid{c}.tiff'
        # p = f'/Users/siddharthsachdeva/Downloads/punjab_skysatimages/{rand_str}_chipid{c}.tiff'
#         p = f'/Users/siddharthsachdeva/Downloads/karnataka_skysatimages/{rand_str}'
        # Then use im.numpy() when writing with rasterio
        with rasterio.open(
            p,
            'w',
            driver='GTiff',
            height=400,
            width=400,
            count=3,  # Assuming im is in C,H,W format
            dtype='uint8',  # Ensure the dtype matches your data
            crs=sample['crs'],
            transform=sample['transform']
        ) as dst:
            dst.write(image)  # Convert tensor to NumPy array for rasterio
#         print(p)
#         im.save(p)
        c += 1

print(c)
# Out:
# 280

# %%
from PIL import Image
import torch
import random
import string
import rasterio

os.makedirs(f'./extra_karnataka/', exist_ok=True)
os.makedirs(f'./extra_karnataka/fill/', exist_ok=True)
os.makedirs(f'./extra_karnataka/overflow/', exist_ok=True)

torch.manual_seed(3)
sampler = GridGeoSampler(dataset, size=400, stride=400)
dataloader = DataLoader(dataset, sampler=sampler, collate_fn=stack_samples)
c = 0
for i, batch in enumerate(dataloader):
    unbinded = unbind_samples(batch)
    sample = unbinded[0]
    im = sample['image']
#     print(sample.keys())
    rand_str = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(10))
    numpixels = im.shape[0] * im.shape[1] * im.shape[2]
    numzero = (im == 0).sum().item()
    ratio = numzero / numpixels
    if ratio < 0.2:
        bds = sample['bounds']
        pt = Point((bds[0] + bds[1]) / 2, (bds[2] + bds[3]) / 2)
        zone = district_to_zone[get_region(data, 'District', pt)]
       
        image = sample["image"][[0,1,2]].numpy().astype('uint8')
       
        # fill up buckets
        if zone in wanted_remaining and wanted_remaining[zone] > 0:
            p = f'./extra_karnataka/fill/{rand_str}_chipid{c}.tiff'
            wanted_remaining[zone] -= 1
        else:
            p = f'./extra_karnataka/overflow/{rand_str}_chipid{c}.tiff'

        with rasterio.open(
            p,
            'w',
            driver='GTiff',
            height=400,
            width=400,
            count=3,  # Assuming im is in C,H,W format
            dtype='uint8',  # Ensure the dtype matches your data
            crs=sample['crs'],
            transform=sample['transform']
        ) as dst:
            dst.write(image)  # Convert tensor to NumPy array for rasterio

        c += 1

print(c)
# Out:
# 732

# %%
print(wanted_remaining)
# Out:
# {'NORTH EAST TRANSITION': 800, 'NORTH EAST DRY': 0, 'NORTHERN DRY': 0, 'CENTRAL DRY': 0, 'EASTERN DRY': 0, 'SOUTHERN DRY': 0, 'SOUTHERN TRANSITION': 0, 'WESTERN TRANSITION': 0, 'HILL': 0, 'COASTAL': 0}

# %%
print(len(os.listdir('./relabeled_tifs/cali_8/')))
# Out:
# 1219

# %%
print(len(os.listdir('./relabeled_tifs/rajasthan/')))
# Out:
# 15045
