# %%
import pandas as pd
from sklearn.metrics import roc_auc_score, roc_curve, average_precision_score
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
truth = pd.read_csv('true_freq.csv')

species = json.load(open('species_vector_mapping.json'))['species_order']
s = [
    (len(truth[truth['species_name'] == sp]) / len(truth), sp)
    for sp in species
]
s.sort()
s.reverse()

df = pd.DataFrame()
df['Species'] = [p[1] for p in s]
df['True Frequency'] = [p[0] for p in s]
# Out:
#                       Species  True Frequency
# 0          Azadirachta indica        0.333106
# 1          Vachellia nilotica        0.227304
# 2          Prosopis cineraria        0.104437
# 3           Ailanthus excelsa        0.095563
# 4          prosopis juliflora        0.044369
# ..                        ...             ...
# 205             Albizia amara        0.000000
# 206         Alangium chinense        0.000000
# 207          Aglaia tomentosa        0.000000
# 208      Adenanthera pavonina        0.000000
# 209  Acrocarpus fraxinifolius        0.000000
#
# [210 rows x 2 columns]

# %%
# load s2 data
root = 'figures/fig2_bioclip'
kshots = [0, 1000, 5000, 11700]

for k in kshots:
    file = f'{root}/subsample_{k}/bio_clip/gsv/100000000000000shots/seed1/predictions/eval_predictions.csv'
    gsv = pd.read_csv(file)

    col = []
    for i, s in enumerate(df['Species']):
        pct = len(gsv[gsv['predicted_class'] == s]) / len(gsv)
        col.append(pct)

    df[f'{k} Shot Frequency'] = col

# %%
df.to_csv('data/annotation_efficiency.csv', index=False)

# %%
truth = pd.read_csv('true_freq.csv')
vector_data = json.load(open('species_vector_mapping.json'))


print(truth['image_filename'])
actual = {
    truth['image_filename'][idx]: truth['species_name'][idx]
    for idx in truth.index
}

print(actual)
print(len(actual))
# Out:
# 0       tree_Pali_Pali_0_10_low_density_far_north_0_20...
# 1       tree_Pali_Pali_0_72_low_density_near_south_0_2...
# 2       tree_Alwar_Alwar_0_118_low_density_near_southe...
# 3       tree_Pali_Pali_0_117_low_density_far_south_0_2...
# 4       tree_Pali_Pali_0_117_low_density_near_west_0_2...
#                               ...
# 1460    tree_Sikar_Sikar_296_1_low_density_near_northe...
# 1461    tree_Sikar_Sikar_305_1_low_density_near_north_...
# 1462    tree_Sikar_Sikar_306_1_low_density_near_north_...
# 1463    tree_Sikar_Sikar_313_0_low_density_near_south_...
# 1464    tree_Sikar_Sikar_393_0_low_density_near_north_...
# Name: image_filename, Length: 1465, dtype: object
# {'tree_Pali_Pali_0_10_low_density_far_north_0_20250526_055530_617380.jpg': 'Aegle Marmelos', 'tree_Pali_Pali_0_72_low_density_near_south_0_20250526_055625_853991.jpg': 'Azadirachta indica', 'tree_Alwar_Alwar_0_118_low_density_near_southeast_0_20250526_055706_494863.jpg': 'Azadirachta indica', 'tree_Pali_Pali_0_117_low_density_far_south_0_20250526_055707_703629.jpg': 'Mangifera indica', 'tree_Pali_Pali_0_117_low_density_near_west_0_20250526_055707_986419.jpg': 'Aegle Marmelos', 'tree_Jhunjhunu_Jhunjhunu_0_210_low_density_far_northeast_0_20250526_055934_550777.jpg': 'Vachellia nilotica', 'tree_Jhunjhunu_Jhunjhunu_0_285_low_density_near_southwest_0_20250526_060045_705153.jpg': 'Prosopis cineraria', 'tree_Jhunjhunu_Jhunjhunu_0_285_low_density_near_west_0_20250526_060046_144992.jpg': 'Prosopis cineraria', 'tree_Nagaur_Nagaur_0_368_low_density_far_southwest_0_20250526_060215_039004.jpg': 'Ailanthus excelsa', 'tree_Nagaur_Nagaur_0_387_low_density_far_southwest_0_20250526_060244_973101.jpg': 'Ficus religiosa', 'tree_Jaipur_Jaipur_1_48_low_density_near_center_0_20250526_060327_556445.jpg': 'Azadirachta indica', 'tree_Nagaur_Nagaur_1_155_low_density_near_center_0_20250526_060452_469831.jpg': 'Vachellia nilotica', 'tree_Nagaur_Nagaur_1_466_low_density_near_southwest_0_20250526_061050_582284.jpg': 'prosopis juliflora', 'tree_Jaipur_Jaipur_2_50_low_density_near_northwest_0_20250526_061255_573075.jpg': 'Albizia procera', 'tree_Jhunjhunu_Jhunjhunu_2_57_low_density_near_northeast_0_20250526_061300_377457.jpg': 'Prosopis cineraria', 'tree_Jhunjhunu_Jhunjhunu_2_67_low_density_far_southwest_0_20250526_061318_182505.jpg': 'Prosopis cineraria', 'tree_Jaipur_Jaipur_2_106_low_density_near_southwest_0_20250526_061405_750582.jpg': 'Vachellia nilotica', 'tree_Jhunjhunu_Jhunjhunu_2_115_low_density_far_northwest_0_20250526_061428_153851.jpg': 'Vachellia nilotica', 'tree_Nagaur_Nagaur_2_119_low_density_near_west_0_20250526_061431_538170.jpg': 'Vachellia nilotica', 'tree_Pali_Pali_2_139_low_density_far_southeast_0_20250526_061452_682401.jpg': 'Azadirachta indica', 'tree_Pali_Pali_2_143_low_density_near_west_0_20250526_061502_004500.jpg': 'Azadirachta indica', 'tree_Jhunjhunu_Jhunjhunu_2_166_low_density_near_southwest_0_20250526_061527_143888.jpg': 'Prosopis cineraria', 'tree_Jhunjhunu_Jhunjhunu_2_328_low_density_near_east_0_20250526_061850_404740.jpg': 'Prosopis cineraria', 'tree_Jaipur_Jaipur_2_400_low_density_far_north_0_20250526_062013_569664.jpg': 'Pongamia pinnata', 'tree_Jaipur_Jaipur_2_457_low_density_near_southeast_0_20250526_062118_701936.jpg': 'Vachellia nilotica', 'tree_Alwar_Alwar_3_36_low_density_far_northeast_0_20250526_062235_017192.jpg': 'Azadirachta indica', 'tree_Jhunjhunu_Jhunjhunu_3_215_low_density_near_north_0_20250526_062509_408111.jpg': 'Prosopis cineraria', 'tree_Jaipur_Jaipur_3_222_low_density_near_north_0_20250526_062524_614929.jpg': 'Ailanthus excelsa', 'tree_Nagaur_Nagaur_3_236_low_density_near_center_0_20250526_062545_525662.jpg': 'prosopis juliflora', 'tree_Pali_Pali_3_396_low_density_near_north_0_20250526_062825_517501.jpg': 'Albizia procera', 'tree_Nagaur_Nagaur_3_401_low_density_near_east_1_20250526_062848_532292.jpg': 'prosopis juliflora', 'tree_Nagaur_Nagaur_3_434_low_density_near_center_0_20250526_062921_191319.jpg': 'Azadirachta indica', 'tree_Nagaur_Nagaur_3_463_low_density_near_center_0_20250526_062934_194526.jpg': 'Ailanthus excelsa', 'tree_Jhunjhunu_Jhunjhunu_3_472_low_density_far_northeast_0_20250526_062948_725630.jpg': 'Dalbergia sissoo', 'tree_Pali_Pali_3_487_low_density_near_east_0_20250526_063006_568263.jpg': 'prosopis juliflora', 'tree_Jaipur_Jaipur_4_51_low_density_near_south_0_20250526_063126_548251.jpg': 'Vachellia nilotica', 'tree_Jaipur_Jaipur_4_52_low_density_near_center_0_20250526_063135_121398.jpg': 'saraca asoca', 'tree_Pali_Pali_4_124_low_density_near_center_0_20250526_063228_087218.jpg': 'Mangifera indica', 'tree_Pali_Pali_4_147_low_density_near_center_0_20250526_063245_907239.jpg': 'Azadirachta ind ...
# 1454

# %%
kshots = [0, 1000, 5000, 11700]

f = open('data/annotation_efficiency.csv', 'w')
f.write("species,k-shots,confidence threshold,left after filtering,percent true in filtered\n")

for k in kshots:
    guesses = json.load(open(f'guesses/guesses_{k}.json'))
    guesses_cleaned = {
        k[k.index('/keep_test/')+11:]: v
        for k, v in guesses.items()
    }

    species_ids = [23, 176, 192, 146, 194]
    for id in species_ids:
        for t in range(47, 70, 1):
            thresh = t / 10000
            num = 0
            den = 0
            for key in actual:
                if guesses_cleaned[key][id] >= thresh:
                    den += 1
                    if actual[key] == vector_data['species_order'][id]:
                        num += 1

            if den > 0:
                f.write(f'{vector_data['species_order'][id]},{k},{thresh},{den},{num / den}\n')

f.close()
